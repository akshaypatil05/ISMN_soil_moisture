# %%
import os
import glob
import math
import pandas as pd
import ee
from tqdm import tqdm

# Initialize Earth Engine
try:
    ee.Initialize()
except Exception as e:
    ee.Authenticate()
    ee.Initialize()

# %%
class SatelliteDataExtractor:
    def __init__(self, start_date, end_date):
        self.start_date = start_date
        self.end_date = end_date

    def mask_s2_clouds(self, image):
        qa = image.select('QA60')
        cloud_bit_mask = 1 << 10
        cirrus_bit_mask = 1 << 11
        mask = qa.bitwiseAnd(cloud_bit_mask).eq(0).And(qa.bitwiseAnd(cirrus_bit_mask).eq(0))
        return image.updateMask(mask).copyProperties(image, ['system:time_start'])

    def compute_s2_indices(self, image, variable):
        indices = {
            'NDVI': image.normalizedDifference(['B8', 'B4']).rename('NDVI'),
            'NDWI': image.normalizedDifference(['B3', 'B8']).rename('NDWI'),
            'NBR':  image.normalizedDifference(['B8', 'B12']).rename('NBR'),
            'MSI':  image.select('B11').divide(image.select('B8')).rename('MSI')
        }
        if variable in indices:
            return image.addBands(indices[variable])
        return image  # For direct bands

    def extract_sentinel2(self, lat, lon, variable, buffer=250):
        point = ee.Geometry.Point([lon, lat])
        region = point.buffer(buffer)

        image_col = ee.ImageCollection('COPERNICUS/S2_SR_HARMONIZED') \
            .filterDate(self.start_date, self.end_date) \
            .filterBounds(region) \
            .filter(ee.Filter.lt('CLOUDY_PIXEL_PERCENTAGE', 20)) \
            .map(self.mask_s2_clouds)

        if variable in ['NDVI', 'NDWI', 'NBR', 'MSI']:
            image_col = image_col.map(lambda img: self.compute_s2_indices(img, variable)).select(variable)
        else:
            image_col = image_col.select(variable)

        def extract_value(image):
            date = ee.Date(image.get('system:time_start')).format('YYYY-MM-dd')
            value = image.reduceRegion(ee.Reducer.mean(), point, scale=10).get(variable)
            return ee.Feature(None, {'date': date, variable: value})

        features = image_col.map(extract_value).filter(ee.Filter.notNull([variable]))
        return features.aggregate_array('date').getInfo(), features.aggregate_array(variable).getInfo()

    def add_layover_shadow_mask(self, image):
        dem = ee.Image('USGS/SRTMGL1_003')
        theta_i = image.select('angle')
        phi_i = ee.Terrain.aspect(dem).select('aspect')
        alpha_s = ee.Terrain.slope(dem).select('slope').multiply(math.pi / 180)
        phi_r = phi_i.multiply(math.pi / 180)
        theta_rad = theta_i.multiply(math.pi / 180)

        layover = phi_r.subtract(theta_rad).abs().lt(math.pi / 2).And(alpha_s.gte(theta_rad.tan().atan()))
        shadow = alpha_s.lte(theta_rad.tan().atan())
        mask = layover.Not().And(shadow.Not())
        return image.updateMask(mask)

    def extract_sentinel1(self, lat, lon, band, buffer=250):
        point = ee.Geometry.Point([lon, lat])
        region = point.buffer(buffer)

        def to_db(image):
            return ee.Image(10).multiply(image.log10()).copyProperties(image, ['system:time_start'])

        def preprocess(image):
            masked = self.add_layover_shadow_mask(image)
            return to_db(masked)

        s1 = ee.ImageCollection('COPERNICUS/S1_GRD') \
            .filterDate(self.start_date, self.end_date) \
            .filterBounds(region) \
            .filter(ee.Filter.eq('instrumentMode', 'IW')) \
            .filter(ee.Filter.eq('orbitProperties_pass', 'DESCENDING')) \
            .filter(ee.Filter.eq('resolution_meters', 10)) \
            .map(preprocess)

        s1_band = s1.select(band)

        def extract_value(image):
            date = ee.Date(image.get('system:time_start')).format('YYYY-MM-dd')
            value = image.reduceRegion(ee.Reducer.mean(), point, scale=10).get(band)
            return ee.Feature(None, {'date': date, band: value})

        features = s1_band.map(extract_value).filter(ee.Filter.notNull([band]))
        return features.aggregate_array('date').getInfo(), features.aggregate_array(band).getInfo()

    def extract_dem(self, lat, lon):
        point = ee.Geometry.Point([lon, lat])
        srtm = ee.Image('USGS/SRTMGL1_003')
        terrain = ee.Terrain.products(srtm)
        slope = terrain.select('slope').reduceRegion(ee.Reducer.mean(), point, scale=30).get('slope').getInfo()
        aspect = terrain.select('aspect').reduceRegion(ee.Reducer.mean(), point, scale=30).get('aspect').getInfo()
        return slope, aspect

def batch_extract(df, extractor, variable):
    results = []
    date_set = set()

    for _, row in tqdm(df.iterrows(), total=len(df)):
        lat, lon, network, station = row['latitude'], row['longitude'], row['network'], row['station']
        try:
            if variable in ['NDVI', 'NDWI', 'NBR', 'MSI', 'B5', 'B6', 'B7', 'B8', 'B2', 'B3', 'B4', 'B11', 'B12']:
                dates, values = extractor.extract_sentinel2(lat, lon, variable)
            elif variable in ['VV', 'VH']:
                dates, values = extractor.extract_sentinel1(lat, lon, band=variable)
            elif variable in ['slope', 'aspect']:
                slope, aspect = extractor.extract_dem(lat, lon)
                results.append({
                    'network': network,
                    'station': station,
                    'Latitude': lat,
                    'Longitude': lon,
                    'slope': slope,
                    'aspect': aspect
                })
                continue

            date_set.update(dates)
            results.append({
                'network': network,
                'station': station,
                'Latitude': lat,
                'Longitude': lon,
                'series': dict(zip(dates, values))
            })
        except Exception as e:
            print(f"Error: {station} → {e}")

    date_list = sorted(date_set)
    normalized = []
    for row in results:
        if 'series' not in row:
            normalized.append(row)
            continue
        record = {
            'network': row['network'],
            'station': row['station'],
            'Latitude': row['Latitude'],
            'Longitude': row['Longitude']
        }
        record.update({d: row['series'].get(d, float('nan')) for d in date_list})
        normalized.append(record)

    return pd.DataFrame(normalized)

# %%
# Main execution loop
root_dir = 'data'
variables = ['NDVI', 'NDWI', 'NBR', 'MSI', 'B5', 'B6', 'B7', 'B8', 'B2', 'B3', 'B4', 'B11', 'B12', 'VV', 'VH', 'slope', 'aspect']
extractor = SatelliteDataExtractor(start_date='2016-06-01', end_date='2025-06-14')

for continent_folder in os.listdir(root_dir):
    continent_path = os.path.join(root_dir, continent_folder)
    if not os.path.isdir(continent_path) or continent_folder == 'satellite_data':
        continue

    input_csv_dir = os.path.join(continent_path, 'extracted_data', 'mean', 'agg_mean')
    if not os.path.exists(input_csv_dir):
        continue

    csv_files = glob.glob(os.path.join(input_csv_dir, '*.csv'))
    for csv_file in csv_files:
        df = pd.read_csv(csv_file)

        for variable in variables:
            output_dir = os.path.join('data', 'satellite_data', continent_folder, variable)
            os.makedirs(output_dir, exist_ok=True)
            output_path = os.path.join(output_dir, os.path.basename(csv_file))

            if os.path.exists(output_path):
                print(f"✅ Skipped (already exists): {output_path}")
                continue

            print(f"🚀 Extracting {variable} for {csv_file}")
            df_result = batch_extract(df, extractor, variable)
            df_result.to_csv(output_path, index=False)
            print(f"✅ Saved: {output_path}")

# %% [markdown]
# ### Modified code to correct the terrainc correction function- no values of VH and VV

# %%
import ee
import math
import pandas as pd
from tqdm import tqdm

class SatelliteDataExtractor:
    def __init__(self, start_date, end_date):
        self.start_date = start_date
        self.end_date = end_date

    def mask_s2_clouds(self, image):
        qa = image.select('QA60')
        cloud_bit_mask = 1 << 10
        cirrus_bit_mask = 1 << 11
        mask = qa.bitwiseAnd(cloud_bit_mask).eq(0).And(qa.bitwiseAnd(cirrus_bit_mask).eq(0))
        return image.updateMask(mask).copyProperties(image, ['system:time_start'])

    def compute_s2_indices(self, image, variable):
        indices = {
            'NDVI': image.normalizedDifference(['B8', 'B4']).rename('NDVI'),
            'NDWI': image.normalizedDifference(['B3', 'B8']).rename('NDWI'),
            'NBR':  image.normalizedDifference(['B8', 'B12']).rename('NBR'),
            'MSI':  image.select('B11').divide(image.select('B8')).rename('MSI')
        }
        if variable in indices:
            return image.addBands(indices[variable])
        return image  # For direct bands

    def extract_sentinel2(self, lat, lon, variable, buffer=250):
        point = ee.Geometry.Point([lon, lat])
        region = point.buffer(buffer)

        image_col = ee.ImageCollection('COPERNICUS/S2_SR_HARMONIZED') \
            .filterDate(self.start_date, self.end_date) \
            .filterBounds(region) \
            .filter(ee.Filter.lt('CLOUDY_PIXEL_PERCENTAGE', 20)) \
            .map(self.mask_s2_clouds)

        if variable in ['NDVI', 'NDWI', 'NBR', 'MSI']:
            image_col = image_col.map(lambda img: self.compute_s2_indices(img, variable)).select(variable)
        else:
            image_col = image_col.select(variable)

        def extract_value(image):
            date = ee.Date(image.get('system:time_start')).format('YYYY-MM-dd')
            value = image.reduceRegion(ee.Reducer.mean(), point, scale=10).get(variable)
            return ee.Feature(None, {'date': date, variable: value})

        features = image_col.map(extract_value).filter(ee.Filter.notNull([variable]))
        return features.aggregate_array('date').getInfo(), features.aggregate_array(variable).getInfo()

    def compute_sar_variables(self, image, ref_angle_deg=35):
        dem = ee.Image("USGS/SRTMGL1_003")
        pi = ee.Number(math.pi)

        sigma0 = ee.Image.constant(10).pow(image.divide(10))
        theta_i = image.select('angle')
        alpha_s = ee.Terrain.slope(dem).select('slope')
        phi_s = ee.Terrain.aspect(dem).select('aspect')
        phi_i = ee.Terrain.aspect(theta_i).reduceRegion(
            reducer=ee.Reducer.mean(), geometry=image.geometry(), scale=1000, maxPixels=1e8
        ).get('aspect')
        phi_i = ee.Image.constant(phi_i)

        phi_r = phi_i.subtract(phi_s)
        theta_i_rad = theta_i.multiply(pi).divide(180)
        alpha_s_rad = alpha_s.multiply(pi).divide(180)
        phi_r_rad = phi_r.multiply(pi).divide(180)
        ref_rad = ee.Number(ref_angle_deg).multiply(pi).divide(180)

        alpha_r = alpha_s_rad.tan().multiply(phi_r_rad.cos()).atan()
        alpha_az = alpha_s_rad.tan().multiply(phi_r_rad.sin()).atan()
        theta_lia_rad = alpha_az.cos().multiply((theta_i_rad.subtract(alpha_r)).cos()).acos()
        theta_lia_deg = theta_lia_rad.multiply(180).divide(pi).rename("local_incidence_angle")

        vv_lin = sigma0.select('VV').rename('VV_sigma0')
        vh_lin = sigma0.select('VH').rename('VH_sigma0')
        vv_dB = image.select('VV').rename('VV_sigma0_dB')
        vh_dB = image.select('VH').rename('VH_sigma0_dB')

        vv_gamma = vv_lin.divide(theta_lia_rad.cos()).rename('VV_gamma0')
        vh_gamma = vh_lin.divide(theta_lia_rad.cos()).rename('VH_gamma0')

        c2_i = theta_lia_rad.cos().pow(2)
        c2_r = ref_rad.cos().pow(2)
        vv_gamma_norm = vv_gamma.multiply(c2_r).divide(c2_i).rename('VV_gamma0_norm')
        vh_gamma_norm = vh_gamma.multiply(c2_r).divide(c2_i).rename('VH_gamma0_norm')

        vh_vv_ratio = vh_lin.divide(vv_lin).multiply(c2_r).divide(c2_i)
        vh_vv_ratio_dB = ee.Image.constant(10).multiply(vh_vv_ratio.log10()).rename('VH_VV_ratio_norm_dB')

        return image.addBands([
            vv_lin, vh_lin, vv_dB, vh_dB,
            vv_gamma, vh_gamma, vv_gamma_norm, vh_gamma_norm,
            theta_lia_deg, vh_vv_ratio_dB
        ])

    def extract_sentinel1(self, lat, lon, band, buffer=250):
        point = ee.Geometry.Point([lon, lat])
        region = point.buffer(buffer)

        def preprocess(image):
            image = self.compute_sar_variables(image)
            return image.copyProperties(image, ['system:time_start'])

        s1 = ee.ImageCollection('COPERNICUS/S1_GRD') \
            .filterDate(self.start_date, self.end_date) \
            .filterBounds(region) \
            .filter(ee.Filter.eq('instrumentMode', 'IW')) \
            .filter(ee.Filter.listContains('transmitterReceiverPolarisation', 'VV')) \
            .filter(ee.Filter.listContains('transmitterReceiverPolarisation', 'VH')) \
            .map(preprocess)

        s1_band = s1.select(band)

        def extract_value(image):
            date = ee.Date(image.get('system:time_start')).format('YYYY-MM-dd')
            value = image.reduceRegion(ee.Reducer.mean(), point, scale=10).get(band)
            return ee.Feature(None, {'date': date, band: value})

        features = s1_band.map(extract_value).filter(ee.Filter.notNull([band]))
        return features.aggregate_array('date').getInfo(), features.aggregate_array(band).getInfo()

    def extract_dem(self, lat, lon):
        point = ee.Geometry.Point([lon, lat])
        srtm = ee.Image('USGS/SRTMGL1_003')
        terrain = ee.Terrain.products(srtm)
        slope = terrain.select('slope').reduceRegion(ee.Reducer.mean(), point, scale=30).get('slope').getInfo()
        aspect = terrain.select('aspect').reduceRegion(ee.Reducer.mean(), point, scale=30).get('aspect').getInfo()
        return slope, aspect

def batch_extract(df, extractor, variable):
    results = []
    date_set = set()

    for _, row in tqdm(df.iterrows(), total=len(df)):
        lat, lon, network, station = row['latitude'], row['longitude'], row['network'], row['station']
        try:
            if variable in ['NDVI', 'NDWI', 'NBR', 'MSI', 'B5', 'B6', 'B7', 'B8', 'B2', 'B3', 'B4', 'B11', 'B12']:
                dates, values = extractor.extract_sentinel2(lat, lon, variable)
            elif variable in ['VV', 'VH', 'VV_sigma0', 'VH_sigma0', 'VV_sigma0_dB', 'VH_sigma0_dB', 'VV_gamma0', 'VH_gamma0', 'VV_gamma0_norm', 'VH_gamma0_norm', 'VH_VV_ratio_norm_dB', 'local_incidence_angle']:
                dates, values = extractor.extract_sentinel1(lat, lon, band=variable)
            elif variable in ['slope', 'aspect']:
                slope, aspect = extractor.extract_dem(lat, lon)
                results.append({
                    'network': network,
                    'station': station,
                    'Latitude': lat,
                    'Longitude': lon,
                    'slope': slope,
                    'aspect': aspect
                })
                continue

            date_set.update(dates)
            results.append({
                'network': network,
                'station': station,
                'Latitude': lat,
                'Longitude': lon,
                'series': dict(zip(dates, values))
            })
        except Exception as e:
            print(f"Error: {station} → {e}")

    date_list = sorted(date_set)
    normalized = []
    for row in results:
        if 'series' not in row:
            normalized.append(row)
            continue
        record = {
            'network': row['network'],
            'station': row['station'],
            'Latitude': row['Latitude'],
            'Longitude': row['Longitude']
        }
        record.update({d: row['series'].get(d, float('nan')) for d in date_list})
        normalized.append(record)

    return pd.DataFrame(normalized)

# %%
import os
import glob
import pandas as pd

# Initialization
root_dir = 'data'
output_root = os.path.join(root_dir, 'satellite_data')
start_date = '2016-06-01'
end_date = '2025-06-14'

variables = [
    'NDVI', 'NDWI', 'NBR', 'MSI', 'B5', 'B6', 'B7', 'B8', 'B2', 'B3', 'B4', 'B11', 'B12',  # Sentinel-2
    'VV_sigma0', 'VH_sigma0', 'VV_sigma0_dB', 'VH_sigma0_dB',                            # S1 Sigma
    'VV_gamma0', 'VH_gamma0', 'VV_gamma0_norm', 'VH_gamma0_norm',                       # Gamma normalized
    'VH_VV_ratio_norm_dB', 'local_incidence_angle',                                      # Additional S1 metrics
    'slope', 'aspect'                                                                    # DEM
]

extractor = SatelliteDataExtractor(start_date=start_date, end_date=end_date)

# Loop over continents and process each station file
for continent_folder in os.listdir(root_dir):
    continent_path = os.path.join(root_dir, continent_folder)
    if not os.path.isdir(continent_path) or continent_folder == 'satellite_data':
        continue

    input_csv_dir = os.path.join(continent_path, 'extracted_data', 'mean', 'agg_mean')
    if not os.path.exists(input_csv_dir):
        continue

    csv_files = glob.glob(os.path.join(input_csv_dir, '*.csv'))
    for csv_file in csv_files:
        df = pd.read_csv(csv_file)
        for variable in variables:
            output_dir = os.path.join(output_root, continent_folder, variable)
            os.makedirs(output_dir, exist_ok=True)

            output_path = os.path.join(output_dir, os.path.basename(csv_file))
            if os.path.exists(output_path):
                print(f"✅ Skipped (already exists): {output_path}")
                continue

            print(f"🚀 Extracting {variable} for {csv_file}")
            df_result = batch_extract(df, extractor, variable)
            df_result.to_csv(output_path, index=False)
            print(f"✅ Saved: {output_path}")
# Out:
# ✅ Skipped (already exists): data\satellite_data\africa\NDVI\AMMA-CATCH.csv
# ✅ Skipped (already exists): data\satellite_data\africa\NDWI\AMMA-CATCH.csv
# ✅ Skipped (already exists): data\satellite_data\africa\NBR\AMMA-CATCH.csv
# ✅ Skipped (already exists): data\satellite_data\africa\MSI\AMMA-CATCH.csv
# ✅ Skipped (already exists): data\satellite_data\africa\B5\AMMA-CATCH.csv
# ✅ Skipped (already exists): data\satellite_data\africa\B6\AMMA-CATCH.csv
# ✅ Skipped (already exists): data\satellite_data\africa\B7\AMMA-CATCH.csv
# ✅ Skipped (already exists): data\satellite_data\africa\B8\AMMA-CATCH.csv
# ✅ Skipped (already exists): data\satellite_data\africa\B2\AMMA-CATCH.csv
# ✅ Skipped (already exists): data\satellite_data\africa\B3\AMMA-CATCH.csv
# ✅ Skipped (already exists): data\satellite_data\africa\B4\AMMA-CATCH.csv
# ✅ Skipped (already exists): data\satellite_data\africa\B11\AMMA-CATCH.csv
# ✅ Skipped (already exists): data\satellite_data\africa\B12\AMMA-CATCH.csv
# ✅ Skipped (already exists): data\satellite_data\africa\VV_sigma0\AMMA-CATCH.csv
# ✅ Skipped (already exists): data\satellite_data\africa\VH_sigma0\AMMA-CATCH.csv
# ✅ Skipped (already exists): data\satellite_data\africa\VV_sigma0_dB\AMMA-CATCH.csv
# ✅ Skipped (already exists): data\satellite_data\africa\VH_sigma0_dB\AMMA-CATCH.csv
# ✅ Skipped (already exists): data\satellite_data\africa\VV_gamma0\AMMA-CATCH.csv
# ✅ Skipped (already exists): data\satellite_data\africa\VH_gamma0\AMMA-CATCH.csv
# ✅ Skipped (already exists): data\satellite_data\africa\VV_gamma0_norm\AMMA-CATCH.csv
# ✅ Skipped (already exists): data\satellite_data\africa\VH_gamma0_norm\AMMA-CATCH.csv
# ✅ Skipped (already exists): data\satellite_data\africa\VH_VV_ratio_norm_dB\AMMA-CATCH.csv
# ✅ Skipped (already exists): data\satellite_data\africa\local_incidence_angle\AMMA-CATCH.csv
# ✅ Skipped (already exists): data\satellite_data\africa\slope\AMMA-CATCH.csv
# ✅ Skipped (already exists): data\satellite_data\africa\aspect\AMMA-CATCH.csv
# ✅ Skipped (already exists): data\satellite_data\africa\NDVI\SD_DEM.csv
# ✅ Skipped (already exists): data\satellite_data\africa\NDWI\SD_DEM.csv
# ✅ Skipped (already exists): data\satellite_data\africa\NBR\SD_DEM.csv
# ✅ Skipped (already exists): data\satellite_data\africa\MSI\SD_DEM.csv
# ✅ Skipped (already exists): data\satellite_data\africa\B5\SD_DEM.csv
# ✅ Skipped (already exists): data\satellite_data\africa\B6\SD_DEM.csv
# ✅ Skipped (already exists): data\satellite_data\africa\B7\SD_DEM.csv
# ✅ Skipped (already exists): data\satellite_data\africa\B8\SD_DEM.csv
# ✅ Skipped (already exists): data\satellite_data\africa\B2\SD_DEM.csv
# ✅ Skipped (already exists): data\satellite_data\africa\B3\SD_DEM.csv
# ✅ Skipped (already exists): data\satellite_data\africa\B4\SD_DEM.csv
# ✅ Skipped (already exists): data\satellite_data\africa\B11\SD_DEM.csv
# ✅ Skipped (already exists): data\satellite_data\africa\B12\SD_DEM.csv
# ✅ Skipped (already exists): data\satellite_data\africa\VV_sigma0\SD_DEM.csv
# ✅ Skipped (already exists): data\satellite_data\africa\VH_sigma0\SD_DEM.csv
# ✅ Skipped (already exists): data\satellite_data\africa\VV_sigma0_dB\SD_DEM.csv
# ✅ Skipped (already exists): data\satellite_data\africa\VH_sigma0_dB\SD_DEM.csv
# ✅ Skipped (already exists): data\satellite_data\africa\VV_gamma0\SD_DEM.csv
# ✅ Skipped (already exists): data\satellite_data\africa\VH_gamma0\SD_DEM.csv
# ✅ Skipped (already exists): data\satellite_data\africa\VV_gamma0_norm\SD_DEM.csv
# ✅ Skipped (already exists): data\satellite_data\africa\VH_gamma0_norm\SD_DEM.csv
# ✅ Skipped (already exists): data\satellite_data\africa\VH_VV_ratio_norm_dB\SD_DEM.csv
# ✅ Skipped (already exists): data\satellite_data\africa\local_incidence_angle\SD_DEM.csv
# ✅ Skipped (already exists): data\satellite_data\africa\slope\SD_DEM.csv
# ✅ Skipped (already exists): data\satellite_data\africa\aspect\SD_DEM.csv
# ✅ Skipped (already exists): data\satellite_data\africa\NDVI\TAHMO.csv
# ✅ Skipped (already exists): data\satellite_data\africa\NDWI\TAHMO.csv
# ✅ Skipped (already exists): data\satellite_data\africa\NBR\TAHMO.csv
# ✅ Skipped (already exists): data\satellite_data\africa\MSI\TAHMO.csv
# ✅ Skipped (already exists): data\satellite_data\africa\B5\TAHMO.csv
# ✅ Skipped (already exists): data\satellite_data\africa\B6\TAHMO.csv
# ✅ Skipped (already exists): data\satellite_data\africa\B7\TAHMO.csv
# ✅ Skipped (already exists): data\satellite_data\africa\B8\TAHMO.csv
# ✅ Skipped (already exists): data\satellite_data\africa\B2\TAHMO.csv
# ✅ Skipped (already exists): data\satellite_data\africa\B3\TAHMO.csv
# ✅ Skipped (already exists): data\satellite_data\africa\B4\TAHMO.csv
# ✅ Skipped (already exists): data\satellite_data\africa\B11\TAHMO.csv
# ✅ Skipped (already exists): data\satellite_data\africa\B12\TAHMO.csv
# ✅ Skipped (already exists): data\satellite_data\africa\VV_sigma0\TAHMO.csv
# ✅ Skipped (already exists): data\satellite_data\africa\VH_sigma0\TAHMO.csv
# ✅ Skipped (already exists): data\satellite_data\africa\VV_sigma0_dB\TAHMO.csv
# ✅ Skipped (already exists): data\satellite_data\africa\VH_sigma0_dB\TAHMO.csv
# ✅ Skipped (already exists): data\satellite_data\africa\VV_gamma0\TAHMO.csv
# ✅ Skipped (already exists): data\satellite_data\africa\VH_gamma0\TAHMO.csv
# ✅ Skipped (already exists): data\satellite_data\africa\VV_gamma0_norm\TAHMO.csv
# ✅ Skipped (already exists): data\satellite_data\africa\VH_gamma0_norm\TAHMO.csv
# ✅ Skipped (already exists): data\satellite_data\africa\VH_VV_ratio_norm_dB\TAHMO.csv
# ✅ Skipped (already exists): data\satellite_data\africa\local_incidence_angle\TAHMO.csv
# ✅ Skipped (already exists): data\satellite_data\africa\slope\TAHMO.csv
# ✅ Skipped (already exists): data\satellite_data\africa\aspect\TAHMO.csv
# ✅ Skipped (already exists): data\satellite_data\asia\NDVI\CTP_SMTMN.csv
# ✅ Skipped (already exists): data\satellite_data\asia\NDWI\CTP_SMTMN.csv
# ✅ Skipped (already exists): data\satellite_data\asia\NBR\CTP_SMTMN.csv
# ✅ Skipped (already exists): data\satellite_data\asia\MSI\CTP_SMTMN.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B5\CTP_SMTMN.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B6\CTP_SMTMN.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B7\CTP_SMTMN.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B8\CTP_SMTMN.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B2\CTP_SMTMN.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B3\CTP_SMTMN.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B4\CTP_SMTMN.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B11\CTP_SMTMN.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B12\CTP_SMTMN.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VV_sigma0\CTP_SMTMN.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VH_sigma0\CTP_SMTMN.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VV_sigma0_dB\CTP_SMTMN.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VH_sigma0_dB\CTP_SMTMN.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VV_gamma0\CTP_SMTMN.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VH_gamma0\CTP_SMTMN.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VV_gamma0_norm\CTP_SMTMN.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VH_gamma0_norm\CTP_SMTMN.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VH_VV_ratio_norm_dB\CTP_SMTMN.csv
# ✅ Skipped (already exists): data\satellite_data\asia\local_incidence_angle\CTP_SMTMN.csv
# ✅ Skipped (already exists): data\satellite_data\asia\slope\CTP_SMTMN.csv
# ✅ Skipped (already exists): data\satellite_data\asia\aspect\CTP_SMTMN.csv
# ✅ Skipped (already exists): data\satellite_data\asia\NDVI\KIHS_CMC.csv
# ✅ Skipped (already exists): data\satellite_data\asia\NDWI\KIHS_CMC.csv
# ✅ Skipped (already exists): data\satellite_data\asia\NBR\KIHS_CMC.csv
# ✅ Skipped (already exists): data\satellite_data\asia\MSI\KIHS_CMC.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B5\KIHS_CMC.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B6\KIHS_CMC.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B7\KIHS_CMC.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B8\KIHS_CMC.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B2\KIHS_CMC.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B3\KIHS_CMC.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B4\KIHS_CMC.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B11\KIHS_CMC.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B12\KIHS_CMC.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VV_sigma0\KIHS_CMC.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VH_sigma0\KIHS_CMC.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VV_sigma0_dB\KIHS_CMC.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VH_sigma0_dB\KIHS_CMC.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VV_gamma0\KIHS_CMC.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VH_gamma0\KIHS_CMC.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VV_gamma0_norm\KIHS_CMC.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VH_gamma0_norm\KIHS_CMC.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VH_VV_ratio_norm_dB\KIHS_CMC.csv
# ✅ Skipped (already exists): data\satellite_data\asia\local_incidence_angle\KIHS_CMC.csv
# ✅ Skipped (already exists): data\satellite_data\asia\slope\KIHS_CMC.csv
# ✅ Skipped (already exists): data\satellite_data\asia\aspect\KIHS_CMC.csv
# ✅ Skipped (already exists): data\satellite_data\asia\NDVI\KIHS_SMC.csv
# ✅ Skipped (already exists): data\satellite_data\asia\NDWI\KIHS_SMC.csv
# ✅ Skipped (already exists): data\satellite_data\asia\NBR\KIHS_SMC.csv
# ✅ Skipped (already exists): data\satellite_data\asia\MSI\KIHS_SMC.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B5\KIHS_SMC.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B6\KIHS_SMC.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B7\KIHS_SMC.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B8\KIHS_SMC.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B2\KIHS_SMC.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B3\KIHS_SMC.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B4\KIHS_SMC.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B11\KIHS_SMC.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B12\KIHS_SMC.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VV_sigma0\KIHS_SMC.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VH_sigma0\KIHS_SMC.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VV_sigma0_dB\KIHS_SMC.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VH_sigma0_dB\KIHS_SMC.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VV_gamma0\KIHS_SMC.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VH_gamma0\KIHS_SMC.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VV_gamma0_norm\KIHS_SMC.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VH_gamma0_norm\KIHS_SMC.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VH_VV_ratio_norm_dB\KIHS_SMC.csv
# ✅ Skipped (already exists): data\satellite_data\asia\local_incidence_angle\KIHS_SMC.csv
# ✅ Skipped (already exists): data\satellite_data\asia\slope\KIHS_SMC.csv
# ✅ Skipped (already exists): data\satellite_data\asia\aspect\KIHS_SMC.csv
# ✅ Skipped (already exists): data\satellite_data\asia\NDVI\MAQU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\NDWI\MAQU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\NBR\MAQU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\MSI\MAQU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B5\MAQU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B6\MAQU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B7\MAQU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B8\MAQU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B2\MAQU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B3\MAQU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B4\MAQU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B11\MAQU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B12\MAQU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VV_sigma0\MAQU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VH_sigma0\MAQU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VV_sigma0_dB\MAQU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VH_sigma0_dB\MAQU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VV_gamma0\MAQU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VH_gamma0\MAQU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VV_gamma0_norm\MAQU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VH_gamma0_norm\MAQU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VH_VV_ratio_norm_dB\MAQU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\local_incidence_angle\MAQU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\slope\MAQU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\aspect\MAQU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\NDVI\NAQU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\NDWI\NAQU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\NBR\NAQU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\MSI\NAQU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B5\NAQU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B6\NAQU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B7\NAQU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B8\NAQU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B2\NAQU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B3\NAQU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B4\NAQU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B11\NAQU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B12\NAQU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VV_sigma0\NAQU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VH_sigma0\NAQU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VV_sigma0_dB\NAQU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VH_sigma0_dB\NAQU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VV_gamma0\NAQU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VH_gamma0\NAQU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VV_gamma0_norm\NAQU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VH_gamma0_norm\NAQU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VH_VV_ratio_norm_dB\NAQU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\local_incidence_angle\NAQU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\slope\NAQU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\aspect\NAQU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\NDVI\NGARI.csv
# ✅ Skipped (already exists): data\satellite_data\asia\NDWI\NGARI.csv
# ✅ Skipped (already exists): data\satellite_data\asia\NBR\NGARI.csv
# ✅ Skipped (already exists): data\satellite_data\asia\MSI\NGARI.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B5\NGARI.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B6\NGARI.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B7\NGARI.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B8\NGARI.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B2\NGARI.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B3\NGARI.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B4\NGARI.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B11\NGARI.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B12\NGARI.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VV_sigma0\NGARI.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VH_sigma0\NGARI.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VV_sigma0_dB\NGARI.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VH_sigma0_dB\NGARI.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VV_gamma0\NGARI.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VH_gamma0\NGARI.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VV_gamma0_norm\NGARI.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VH_gamma0_norm\NGARI.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VH_VV_ratio_norm_dB\NGARI.csv
# ✅ Skipped (already exists): data\satellite_data\asia\local_incidence_angle\NGARI.csv
# ✅ Skipped (already exists): data\satellite_data\asia\slope\NGARI.csv
# ✅ Skipped (already exists): data\satellite_data\asia\aspect\NGARI.csv
# ✅ Skipped (already exists): data\satellite_data\asia\NDVI\SKKU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\NDWI\SKKU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\NBR\SKKU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\MSI\SKKU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B5\SKKU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B6\SKKU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B7\SKKU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B8\SKKU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B2\SKKU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B3\SKKU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B4\SKKU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B11\SKKU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B12\SKKU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VV_sigma0\SKKU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VH_sigma0\SKKU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VV_sigma0_dB\SKKU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VH_sigma0_dB\SKKU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VV_gamma0\SKKU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VH_gamma0\SKKU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VV_gamma0_norm\SKKU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VH_gamma0_norm\SKKU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VH_VV_ratio_norm_dB\SKKU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\local_incidence_angle\SKKU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\slope\SKKU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\aspect\SKKU.csv
# ✅ Skipped (already exists): data\satellite_data\asia\NDVI\SMN-SDR.csv
# ✅ Skipped (already exists): data\satellite_data\asia\NDWI\SMN-SDR.csv
# ✅ Skipped (already exists): data\satellite_data\asia\NBR\SMN-SDR.csv
# ✅ Skipped (already exists): data\satellite_data\asia\MSI\SMN-SDR.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B5\SMN-SDR.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B6\SMN-SDR.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B7\SMN-SDR.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B8\SMN-SDR.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B2\SMN-SDR.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B3\SMN-SDR.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B4\SMN-SDR.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B11\SMN-SDR.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B12\SMN-SDR.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VV_sigma0\SMN-SDR.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VH_sigma0\SMN-SDR.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VV_sigma0_dB\SMN-SDR.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VH_sigma0_dB\SMN-SDR.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VV_gamma0\SMN-SDR.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VH_gamma0\SMN-SDR.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VV_gamma0_norm\SMN-SDR.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VH_gamma0_norm\SMN-SDR.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VH_VV_ratio_norm_dB\SMN-SDR.csv
# ✅ Skipped (already exists): data\satellite_data\asia\local_incidence_angle\SMN-SDR.csv
# ✅ Skipped (already exists): data\satellite_data\asia\slope\SMN-SDR.csv
# ✅ Skipped (already exists): data\satellite_data\asia\aspect\SMN-SDR.csv
# ✅ Skipped (already exists): data\satellite_data\asia\NDVI\SONTE-China.csv
# ✅ Skipped (already exists): data\satellite_data\asia\NDWI\SONTE-China.csv
# ✅ Skipped (already exists): data\satellite_data\asia\NBR\SONTE-China.csv
# ✅ Skipped (already exists): data\satellite_data\asia\MSI\SONTE-China.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B5\SONTE-China.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B6\SONTE-China.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B7\SONTE-China.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B8\SONTE-China.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B2\SONTE-China.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B3\SONTE-China.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B4\SONTE-China.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B11\SONTE-China.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B12\SONTE-China.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VV_sigma0\SONTE-China.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VH_sigma0\SONTE-China.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VV_sigma0_dB\SONTE-China.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VH_sigma0_dB\SONTE-China.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VV_gamma0\SONTE-China.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VH_gamma0\SONTE-China.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VV_gamma0_norm\SONTE-China.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VH_gamma0_norm\SONTE-China.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VH_VV_ratio_norm_dB\SONTE-China.csv
# ✅ Skipped (already exists): data\satellite_data\asia\local_incidence_angle\SONTE-China.csv
# ✅ Skipped (already exists): data\satellite_data\asia\slope\SONTE-China.csv
# ✅ Skipped (already exists): data\satellite_data\asia\aspect\SONTE-China.csv
# ✅ Skipped (already exists): data\satellite_data\asia\NDVI\VDS.csv
# ✅ Skipped (already exists): data\satellite_data\asia\NDWI\VDS.csv
# ✅ Skipped (already exists): data\satellite_data\asia\NBR\VDS.csv
# ✅ Skipped (already exists): data\satellite_data\asia\MSI\VDS.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B5\VDS.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B6\VDS.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B7\VDS.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B8\VDS.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B2\VDS.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B3\VDS.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B4\VDS.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B11\VDS.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B12\VDS.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VV_sigma0\VDS.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VH_sigma0\VDS.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VV_sigma0_dB\VDS.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VH_sigma0_dB\VDS.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VV_gamma0\VDS.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VH_gamma0\VDS.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VV_gamma0_norm\VDS.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VH_gamma0_norm\VDS.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VH_VV_ratio_norm_dB\VDS.csv
# ✅ Skipped (already exists): data\satellite_data\asia\local_incidence_angle\VDS.csv
# ✅ Skipped (already exists): data\satellite_data\asia\slope\VDS.csv
# ✅ Skipped (already exists): data\satellite_data\asia\aspect\VDS.csv
# ✅ Skipped (already exists): data\satellite_data\asia\NDVI\WIT-Network.csv
# ✅ Skipped (already exists): data\satellite_data\asia\NDWI\WIT-Network.csv
# ✅ Skipped (already exists): data\satellite_data\asia\NBR\WIT-Network.csv
# ✅ Skipped (already exists): data\satellite_data\asia\MSI\WIT-Network.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B5\WIT-Network.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B6\WIT-Network.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B7\WIT-Network.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B8\WIT-Network.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B2\WIT-Network.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B3\WIT-Network.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B4\WIT-Network.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B11\WIT-Network.csv
# ✅ Skipped (already exists): data\satellite_data\asia\B12\WIT-Network.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VV_sigma0\WIT-Network.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VH_sigma0\WIT-Network.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VV_sigma0_dB\WIT-Network.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VH_sigma0_dB\WIT-Network.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VV_gamma0\WIT-Network.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VH_gamma0\WIT-Network.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VV_gamma0_norm\WIT-Network.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VH_gamma0_norm\WIT-Network.csv
# ✅ Skipped (already exists): data\satellite_data\asia\VH_VV_ratio_norm_dB\WIT-Network.csv
# ✅ Skipped (already exists): data\satellite_data\asia\local_incidence_angle\WIT-Network.csv
# ✅ Skipped (already exists): data\satellite_data\asia\slope\WIT-Network.csv
# ✅ Skipped (already exists): data\satellite_data\asia\aspect\WIT-Network.csv
